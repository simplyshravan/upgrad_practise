# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv(r'Cricket.csv',encoding='cp1252')

# %%
df.head()
# Out:
#                         Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144  33.37
#
#       BF     SR  100  50   0
# 0  21367  86.23   49  96  20
# 1  18048  78.86   25  93  15
# 2  17046  80.39   30  82  20
# 3  14725  91.20   28  68  34
# 4  16020  78.96   19  77  28

# %%
df_train=df[['Ave','SR']]
standard_scaler=StandardScaler()
df_final=standard_scaler.fit_transform(df_train)

# %%
df_scaled = pd.DataFrame(df_final)

# %%
# k-means with some arbitrary k
kmeans = KMeans(n_clusters=4,random_state=100)
kmeans.fit(df_scaled)
# Out:
# KMeans(n_clusters=4, random_state=100)

# %%
kmeans.labels_
# Out:
# array([3, 1, 1, 0, 2, 1, 1, 1, 1, 1, 0, 1, 0, 3, 2, 3, 2, 0, 1, 1, 0, 1,
#        2, 1, 0, 3, 2, 0, 2, 1, 2, 2, 1, 2, 3, 2, 2, 1, 3, 1, 2, 2, 3, 2,
#        2, 2, 1, 2, 2, 1, 0, 1, 2, 2, 2, 2, 1, 0, 2, 0, 2, 0, 1, 3, 3, 1,
#        1, 2, 1, 2, 1, 2, 2, 2, 1, 1, 2, 0, 2])

# %%
df['cluster_id'] = kmeans.labels_

# %%
df[df['cluster_id']==3]
# Out:
#                      Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0      SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 13    MS Dhoni (Asia/INDIA)  2004-2017  295   255  70   9496  183*  51.32
# 15  AB de Villiers (Afr/SA)  2005-2017  222   213  39   9319  162*  53.55
# 25          V Kohli (INDIA)  2008-2017  188   180  29   8146   183  53.94
# 34             HM Amla (SA)  2008-2017  156   153  10   7186   159  50.25
# 38           MG Bevan (AUS)  1994-2004  232   196  67   6912  108*  53.58
# 42        IVA Richards (WI)  1975-1991  187   167  24   6721  189*  47.00
# 63          MJ Guptill (NZ)  2009-2017  146   143  16   5500  237*  43.30
# 64         MEK Hussey (AUS)  2004-2012  185   157  44   5442  109*  48.15
#
#        BF      SR  100  50   0  cluster_id
# 0   21367   86.23   49  96  20           3
# 13  10706   88.69   10  64   8           3
# 15   9295  100.25   24  53   7           3
# 25   8952   90.99   27  43  11           3
# ...

# %%
# plot
sns.boxplot(x='cluster_id', y='Ave', data=df)
# Out:
# <AxesSubplot:xlabel='cluster_id', ylabel='Ave'>

# %%
# plot
sns.boxplot(x='cluster_id', y='SR', data=df)
# Out:
# <AxesSubplot:xlabel='cluster_id', ylabel='SR'>

# %%
df[df['cluster_id']==1]
# Out:
#                          Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 1   KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2          RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 5     Inzamam-ul-Haq (Asia/PAK)  1991-2007  378   350  53  11739  137*  39.52
# 6        JH Kallis (Afr/ICC/SA)  1996-2014  328   314  53  11579   139  44.36
# 7       SC Ganguly (Asia/INDIA)  1992-2007  311   300  23  11363   183  41.02
# 8     R Dravid (Asia/ICC/INDIA)  1996-2011  344   318  40  10889   153  39.16
# 9              BC Lara (ICC/WI)  1990-2007  299   289  32  10405   169  40.48
# 11   Mohammad Yousuf (Asia/PAK)  1998-2010  288   273  40   9720  141*  41.71
# 18            Saeed Anwar (PAK)  1989-2003  247   244  19   8824   194  39.21
# 19           S Chanderpaul (WI)  1994-2011  268   251  40   8778   150  41.60
# 21               DL Haynes (WI)  1978-1994  238   237  28   8648  152*  41.37
# ...

# %%
df[df['cluster_id']==0]
# Out:
#                           Player       Span  Mat  Inns  NO   Runs    HS  \
# 3        ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189
# 10               TM Dilshan (SL)  1999-2016  330   303  41  10290  161*
# 12        AC Gilchrist (AUS/ICC)  1996-2008  287   279  11   9619   172
# 17             CH Gayle (ICC/WI)  1999-2015  269   264  17   9221   215
# 20     Yuvraj Singh (Asia/INDIA)  2000-2017  304   278  40   8701   150
# 24     V Sehwag (Asia/ICC/INDIA)  1999-2013  251   245   9   8273   219
# 27  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398   369  27   8064   124
# 50              BB McCullum (NZ)  2002-2016  260   228  28   6083   166
# 57          EJG Morgan (ENG/IRE)  2006-2017  185   174  25   5772  124*
# 59               SR Watson (AUS)  2002-2015  190   169  27   5757  185*
# 61              SK Raina (INDIA)  2005-2015  223   192  35   5568  116*
# 77               A Symonds (AUS)  1998-2009  198   161  33   5088   156
#
# ...

# %%
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

# %%
mergings = linkage(df_scaled, method="complete", metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
# 3 clusters
cluster_labels = cut_tree(mergings, n_clusters=4).reshape(-1, )
cluster_labels
# Out:
# array([0, 0, 0, 1, 2, 0, 0, 0, 0, 0, 0, 0, 1, 3, 2, 3, 2, 0, 0, 0, 0, 0,
#        0, 0, 1, 3, 0, 1, 2, 0, 2, 2, 0, 2, 3, 2, 2, 0, 3, 0, 2, 2, 0, 2,
#        2, 2, 0, 2, 2, 0, 1, 0, 0, 2, 2, 2, 0, 0, 2, 0, 2, 1, 0, 0, 0, 0,
#        0, 0, 0, 2, 0, 2, 2, 2, 0, 0, 2, 0, 2])

# %%
df['cluster_labels'] = cluster_labels
df.head()
# Out:
#                         Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144  33.37
#
#       BF     SR  100  50   0  cluster_id  cluster_labels
# 0  21367  86.23   49  96  20           3               0
# 1  18048  78.86   25  93  15           1               0
# 2  17046  80.39   30  82  20           1               0
# 3  14725  91.20   28  68  34           0               1
# 4  16020  78.96   19  77  28           2               2

# %%
df[df['cluster_labels']==0]
# Out:
#                          Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0          SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1   KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2          RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 5     Inzamam-ul-Haq (Asia/PAK)  1991-2007  378   350  53  11739  137*  39.52
# 6        JH Kallis (Afr/ICC/SA)  1996-2014  328   314  53  11579   139  44.36
# 7       SC Ganguly (Asia/INDIA)  1992-2007  311   300  23  11363   183  41.02
# 8     R Dravid (Asia/ICC/INDIA)  1996-2011  344   318  40  10889   153  39.16
# 9              BC Lara (ICC/WI)  1990-2007  299   289  32  10405   169  40.48
# 10              TM Dilshan (SL)  1999-2016  330   303  41  10290  161*  39.27
# 11   Mohammad Yousuf (Asia/PAK)  1998-2010  288   273  40   9720  141*  41.71
# 17            CH Gayle (ICC/WI)  1999-2015  269   264  17   9221   215  37.33
# ...

# %%
df[df['cluster_labels']==1]
# Out:
#                           Player       Span  Mat  Inns  NO   Runs    HS  \
# 3        ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189
# 12        AC Gilchrist (AUS/ICC)  1996-2008  287   279  11   9619   172
# 24     V Sehwag (Asia/ICC/INDIA)  1999-2013  251   245   9   8273   219
# 27  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398   369  27   8064   124
# 50              BB McCullum (NZ)  2002-2016  260   228  28   6083   166
# 61              SK Raina (INDIA)  2005-2015  223   192  35   5568  116*
#
#       Ave     BF      SR  100  50   0  cluster_id  cluster_labels
# 3   32.36  14725   91.20   28  68  34           0               1
# 12  35.89   9922   96.94   16  55  19           0               1
# 24  35.05   7929  104.33   15  38  14           0               1
# 27  23.57   6892  117.00    6  39  30           0               1
# 50  30.41   6312   96.37    5  32  20           0               1
# 61  35.46   5938   93.76    5  36  14           0               1

# %%
df[df['cluster_labels']==2]
# Out:
#                         Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144  33.37
# 14        M Azharuddin (INDIA)  1985-2000  334   308  54   9378  153*  36.92
# 16            PA de Silva (SL)  1984-2003  308   296  30   9284   145  34.90
# 28         SP Fleming (ICC/NZ)  1994-2007  280   269  21   8037  134*  32.40
# 30              SR Waugh (AUS)  1986-2002  325   288  58   7569  120*  32.90
# 31            A Ranatunga (SL)  1982-1999  269   255  47   7456  131*  35.84
# 33           Younis Khan (PAK)  2000-2015  265   255  23   7249   144  31.24
# 35          Saleem Malik (PAK)  1982-1999  283   256  38   7170   102  32.88
# 36               NJ Astle (NZ)  1995-2007  223   217  14   7090  145*  34.92
# 40              A Flower (ZIM)  1992-2003  213   208  16   6786   145  35.34
# 41          Shoaib Malik (PAK)  1999-2017  252   228  36   6765   143  35.23
# ...

# %%
df[df['cluster_labels']==3]
# Out:
#                      Player       Span  Mat  Inns  NO  Runs    HS    Ave  \
# 13    MS Dhoni (Asia/INDIA)  2004-2017  295   255  70  9496  183*  51.32
# 15  AB de Villiers (Afr/SA)  2005-2017  222   213  39  9319  162*  53.55
# 25          V Kohli (INDIA)  2008-2017  188   180  29  8146   183  53.94
# 34             HM Amla (SA)  2008-2017  156   153  10  7186   159  50.25
# 38           MG Bevan (AUS)  1994-2004  232   196  67  6912  108*  53.58
#
#        BF      SR  100  50   0  cluster_id  cluster_labels
# 13  10706   88.69   10  64   8           3               3
# 15   9295  100.25   24  53   7           3               3
# 25   8952   90.99   27  43  11           3               3
# 34   8069   89.05   25  33   3           3               3
# 38   9320   74.16    6  46   5           3               3
